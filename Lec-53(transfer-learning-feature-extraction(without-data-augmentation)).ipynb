# %%
# Used Goggle Gollab for
# 1. transfer-learning-feature-extraction(without-data-augmentation)
# 2. transfer-learning-feature-extraction(data-augmentation)
# 3. transfer-learning-feature-extraction(Fine-Tunning)
